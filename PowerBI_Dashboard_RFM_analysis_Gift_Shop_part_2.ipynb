# %% [markdown]
# <a href="https://colab.research.google.com/github/palienko105/Projects/blob/main/PowerBI_Dashboard_RFM_analysis_Gift_Shop_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets/ilkeryildiz/online-retail-listing?resource=download

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # На основе данных, полученных в предыдущем блокноте ('RFM_analysis_Gift_Shop_Python_SQL_part_1.ipynb'), был создан отчет в Power BI. Данный отчет позволяет в удобном виде просматривать и анализировать результаты.

# %%
url = 'https://docs.google.com/spreadsheets/d/1R3Dvyjt15WT7ueaTskvyYXtk2l1mANor/edit?usp=sharing&ouid=106493810533067665237&rtpof=true&sd=true'

# %%
# !gdown --id 1R3Dvyjt15WT7ueaTskvyYXtk2l1mANor
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1R3Dvyjt15WT7ueaTskvyYXtk2l1mANor
# To: /content/shop2009.xlsx
# 100% 2.95M/2.95M [00:00<00:00, 213MB/s]

# %%
df = pd.read_excel('/content/shop2009.xlsx')

# %%
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 2       489434    79323W                  WHITE CHERRY LIGHTS        12
# 3       489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4       489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...        ...       ...                                  ...       ...
# 30756   493395     21973     SET OF 36 MUSHROOM PAPER DOILIES        12
# 30757   493395     21974     SET OF 36 PAISLEY FLOWER DOILIES        12
# 30758   493395     21976       PACK OF 60 MUSHROOM CAKE CASES        24
# 30759   493395     21299          EDWARDIAN TOILET ROLL UNIT          4
# 30760   493395     21039              RED SPOTTY SHOPPING BAG        12
#
#               InvoiceDate  Price  Customer ID         Country  \
# ...

# %% [markdown]
# ![Отчет1_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Отчет1_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Отчет1_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Отчет1_4.jpg](data:image/jpeg;base64,...)
